# %%
#importing the commo libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the data
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# We see that there are no null values.

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# Univariate analysis

# %%
sns.histplot(x='age', data = df, kde = True, bins = 20)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.distplot(df['expenses'])
# Out:
# C:\Users\vcyad\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='expenses', ylabel='Density'>

# %% [markdown]
# distribution of the feature expenses is right skewed

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['bmi'], kde = True)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Count'>

# %%
#checking for outliers in the feature 'bmi'
sns.boxplot(df['bmi'])
# Out:
# C:\Users\vcyad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %%
print(df['region'].unique())
print(df['region'].value_counts())
# Out:
# ['southwest' 'southeast' 'northwest' 'northeast']
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.countplot(df['region'])
# Out:
# C:\Users\vcyad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
sns.countplot(df['smoker'])
# Out:
# C:\Users\vcyad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# There are more non smokers than smokers.

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
sns.countplot(df['children'])
# Out:
# C:\Users\vcyad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='children', ylabel='count'>

# %% [markdown]
# Bivariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#sex vs expenses
sns.barplot(x='sex',y='expenses',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='expenses'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='smoker',hue = 'sex',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
#smoker vs expenses
sns.barplot(x='smoker',y='expenses',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='expenses'>

# %% [markdown]
# Expenses of smokers are high.

# %%
#children vs expenses
sns.barplot(x='children',y='expenses',data=df)
# Out:
# <AxesSubplot:xlabel='children', ylabel='expenses'>

# %% [markdown]
# Expenses of people having 3 children is the highest, and people having 2 children are also comparitively higher.

# %%
#region vs expenses
sns.barplot(x='region',y='expenses',data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='expenses'>

# %% [markdown]
# Expenses of southeast region has highest expenses, followed by northeast, northwest and southwest

# %%
#age vs expenses
sns.scatterplot(x=df['age'],y=df['expenses'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.regplot(x='age',y='expenses',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
sns.regplot(x='bmi',y='expenses',data=df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
plt.title("Non-Smokers BMI vs Expenses",fontsize=15)
non_smokers_bmi=df[df['smoker']=='no']
sns.regplot(x='bmi',y='expenses',data=non_smokers_bmi)
# Out:
# <AxesSubplot:title={'center':'Non-Smokers BMI vs Expenses'}, xlabel='bmi', ylabel='expenses'>

# %%
plt.title("Smokers BMI vs Expenses",fontsize=15)
smokers_bmi=df[df['smoker']=='yes']
sns.regplot(x='bmi',y='expenses',data=smokers_bmi)
# Out:
# <AxesSubplot:title={'center':'Smokers BMI vs Expenses'}, xlabel='bmi', ylabel='expenses'>

# %% [markdown]
# Expenses increase as bmi increases.

# %%
#pairplot
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.boxplot(data=df, x = 'expenses')
# Out:
# <AxesSubplot:xlabel='expenses'>

# %% [markdown]
# bmi has outliers

# %% [markdown]
# Converting object type to int

# %%
print(df['sex'].unique())
print(df['smoker'].unique())
print(df['region'].unique())
# Out:
# ['female' 'male']
# ['yes' 'no']
# ['southwest' 'southeast' 'northwest' 'northeast']

# %%
df['sex'] = df['sex'].map({'female':0,'male':1})
df['smoker'] = df['smoker'].map({'yes':0,'no':1})
df['region'] = df['region'].map({'southwest':0,'southeast':1,'northwest':2,'northeast':3})

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       0       0  16884.92
# 1   18    1  33.8         1       1       1   1725.55
# 2   28    1  33.0         3       1       1   4449.46
# 3   33    1  22.7         0       1       2  21984.47
# 4   32    1  28.9         0       1       2   3866.86
